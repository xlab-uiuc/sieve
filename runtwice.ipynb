# %%
import jsondiff as jd
import json
from deepdiff import DeepDiff
import copy
import oracle
import io

# %%
learn1 = json.loads(open("resources.json").read())
learn2 = json.loads(open("resources-double.json").read())
test = json.loads(open("resources_test.json").read())

# %%
ddiff = DeepDiff(learn1, learn2, ignore_order=False, view='tree')
ddiff.keys()
# Out:
# dict_keys(['dictionary_item_added', 'dictionary_item_removed', 'values_changed'])

# %%
def look_for_resources_diff(learn, test):
    f = io.StringIO()
    learn_trim = copy.deepcopy(learn)
    test_trim = copy.deepcopy(test)
    diff = jd.diff(learn_trim, test_trim, syntax="symmetric")

    print("[RESOURCE DIFF REPORT]", file=f)
    for rtype in diff:
        rdiff = diff[rtype]
        # Check for resource level delete/insert
        if jd.delete in rdiff:
            # Any resource deleted
            for (idx, item) in rdiff[jd.delete]:
                print(
                    "[resource deleted]",
                    rtype,
                    item["metadata"]["namespace"],
                    item["metadata"]["name"],
                    file=f,
                )
        if jd.insert in rdiff:
            # Any resource added
            for (idx, item) in rdiff[jd.insert]:
                print(
                    "[resource added]",
                    rtype,
                    item["metadata"]["namespace"],
                    item["metadata"]["name"],
                    file=f,
                )

        # Check for resource internal fields
        for idx in rdiff:
            if not type(idx) is int:
                continue
            resource = test[rtype][idx]
            name = resource["metadata"]["name"]
            namespace = resource["metadata"]["namespace"]
            item = rdiff[idx]
            for majorfield in item:
                if majorfield == jd.delete:
                    print("[field deleted]", item[majorfield], file=f)
                    continue
                if majorfield == jd.insert:
                    print("[field added]", item[majorfield], file=f)
                    continue
                data = item[majorfield]
                for subfield in data:
                    if True:
                        if type(data[subfield]) is list:
                            if 'SIEVE-IGNORE' in data[subfield][0]:
                                continue
                        if 'SIEVE-IGNORE' in str(data[subfield]):
                            continue
                        print(
                            "[%s field changed]" % (majorfield),
                            rtype,
                            name,
                            subfield,
                            "changed",
                            "delta: ",
                            data[subfield],
                            file=f,
                        )
                if jd.delete in data:
                    print(
                        "[%s field deleted]" % (majorfield),
                        rtype,
                        name,
                        data[jd.delete],
                        file=f,
                    )
                if jd.insert in data:
                    print(
                        "[%s field added]" % (majorfield),
                        rtype,
                        name,
                        data[jd.insert],
                        file=f,
                    )

    result = f.getvalue()
    f.close()
    return result

# %%
def nested_set(dic, keys, value):
    for key in keys[:-1]:
        dic = dic[key]
    dic[keys[-1]] = value

stored_learn = copy.deepcopy(learn2)
for key in ddiff['values_changed']:
#     print(key.path(output_format='list'))
    nested_set(stored_learn, key.path(output_format='list'), "SIEVE-IGNORE")
    
for key in ddiff['dictionary_item_added']:
#     print(key.path(output_format='list'))
    nested_set(stored_learn, key.path(output_format='list'), "SIEVE-IGNORE")
    
# stored_learn
print(look_for_resources_diff(stored_learn, test))
# Out:
# [RESOURCE DIFF REPORT]
# [metadata field changed] deployment nifikop-operator annotations changed delta:  {delete: {'meta.helm.sh/release-name': 'nifikop-operator', 'meta.helm.sh/release-namespace': 'default'}}
# [spec field changed] deployment nifikop-operator template changed delta:  {'spec': {'containers': {0: {'image': ['laphets/nifikop-operator:learn', 'laphets/nifikop-operator:atomicity-violation']}}}}
# [metadata field changed] pod nifikop-operator-6b7697f96-pssvk generateName changed delta:  ['nifikop-operator-6756f8bf87-', 'nifikop-operator-6b7697f96-']
# [metadata field changed] pod nifikop-operator-6b7697f96-pssvk labels changed delta:  {'pod-template-hash': ['6756f8bf87', '6b7697f96']}
# [spec field changed] pod nifikop-operator-6b7697f96-pssvk nodeName changed delta:  ['kind-worker', 'kind-worker2']
# [status field changed] pod nifikop-operator-6b7697f96-pssvk hostIP changed delta:  ['172.18.0.2', '172.18.0.3']
# [status field changed] pod simplenifi-1-nodeq5jbw hostIP changed delta:  ['172.18.0.2', '172.18.0.4']

# %%
learn = json.loads(open("resources_rl.json").read())
test = json.loads(open("resources_rt.json").read())

import deepdiff

def nested_get(dic, keys):    
    for key in keys:
        dic = dic[key]
    return dic

tdiff = DeepDiff(learn, test, ignore_order=False, view='tree')
stored_test = copy.deepcopy(test)
not_care_keys = set(['annotations', 'managedFields', 'image', 'imageID', 'nodeName', 'hostIP', 'message', 'labels', 'generateName', 'ownerReferences'])

# not_care_keys = set()

for t in tdiff:
    for key in tdiff[t]:
#         print(key)
        path = key.path(output_format='list')
        if key.t1 != "SIEVE-IGNORE":
            has_not_care = False
            for kp in path:
                if kp in not_care_keys:
                    has_not_care = True
                    break
            if has_not_care:
                continue
            rType = path[0]
            print(key.t2)
            if str(key.t2) == 'not present':
                print("12233232", type(key.t2))
            
            if len(path) == 2 and type(key.t2) is deepdiff.helper.NotPresent:
                source = learn
            else:
                source = test

            print(t, path, len(test['persistentvolumeclaim']))
            print(key.t1)
            name = nested_get(source, path[:2] + ['metadata', 'name'])
            namespace = nested_get(source, path[:2] + ['metadata', 'namespace'])
            print(t, rType, namespace, name, path, key.t1, " => ", key.t2)
# Out:
# not present
# 12233232 <class 'deepdiff.helper.NotPresent'>
# iterable_item_removed ['persistentvolumeclaim', 2] 2
# {'metadata': {'creationTimestamp': 'SIEVE-IGNORE', 'finalizers': ['kubernetes.io/pvc-protection'], 'labels': {'app.kubernetes.io/component': 'rabbitmq', 'app.kubernetes.io/name': 'rabbitmq-cluster', 'app.kubernetes.io/part-of': 'rabbitmq'}, 'managedFields': [{'apiVersion': 'v1', 'fieldsType': 'FieldsV1', 'fieldsV1': {'f:metadata': {'f:labels': {'.': {}, 'f:app.kubernetes.io/component': {}, 'f:app.kubernetes.io/name': {}, 'f:app.kubernetes.io/part-of': {}}, 'f:ownerReferences': {'.': {}, 'k:{"uid":"3366d479-0665-4ae8-a773-24536e20fa9b"}': 'SIEVE-IGNORE'}}, 'f:spec': {'f:accessModes': {}, 'f:resources': {'f:requests': {'.': {}, 'f:storage': {}}}, 'f:volumeMode': {}}, 'f:status': {'f:phase': {}}}, 'manager': 'kube-controller-manager', 'operation': 'Update', 'time': 'SIEVE-IGNORE'}], 'name': 'persistence-rabbitmq-cluster-server-2', 'namespace': 'default', 'ownerReferences': [{'apiVersion': 'rabbitmq.com/v1beta1', 'blockOwnerDeletion': False, 'controller': True, 'kind': 'RabbitmqCluster', 'name': 'rabbitmq-cluster', 'uid': 'SIEVE-IGNORE'}], 'resourceVersion': 'SIEVE-IGNORE', 'selfLink': '/api/v1/namespaces/default/persistentvolumeclaims/persistence-rabbitmq-cluster-server-2', 'uid': 'SIEVE-IGNORE'}, 'spec': {'accessModes': ['ReadWriteOnce'], 'resources': {'requests': {'storage': '10Gi'}}, 'storageClassName': 'standard', 'volumeMode': 'Filesystem'}, 'status': {'phase': 'Pending'}}
# iterable_item_removed persistentvolumeclaim default persistence-rabbitmq-cluster-server-2 ['persistentvolumeclaim', 2] {'metadata': {'creationTimestamp': 'SIEVE-IGNORE', 'finalizers': ['kubernetes.io/pvc-protection'], 'labels': {'app.kubernetes.io/component': 'rabbitmq', 'app.kubernetes.io/name': 'rabbitmq-cluster', 'app.kubernetes.io/part-of': 'rabbitmq'}, 'managedFields': [{'apiVersion': 'v1', 'fieldsType': 'FieldsV1', 'fieldsV1': {'f:metadata': {'f:labels': {'.': {}, 'f:app.kubernetes.io/component': {}, 'f:app.kubernetes.io/name': {}, 'f:app.kubernetes.io/part-of': {}}, 'f:ownerReferences': {'.': {}, 'k:{"uid":"3366d479-0665-4ae8-a773-24536e20fa9b"}': 'SIEVE-IGNORE'}}, 'f:spec': {'f:accessModes': {}, 'f:resources': {'f:requests': {'.': {}, 'f:storage': {}}}, 'f:volumeMode': {}}, 'f:status': {'f:phase': {}}}, 'manager': 'kube-controller-manager', 'operation': 'Update', 'time': 'SIEVE-IGNORE'}], 'name': 'persistence-rabbitmq-cluster-server-2', 'namespace': 'default', 'ownerReferences': [{'apiVersion': 'rabbitmq.com/v1beta1', 'blockOwnerDeletion': False, 'controller': True, 'kind': 'RabbitmqCluster', 'name': 'rabbitmq-cluster', 'uid': 'SIEVE-IGNORE'}], 'resourceVersion': 'SIEVE-IGNORE', 'selfLink': '/api/v1/namespaces/default/persistentvolumeclaims/persistence-rabbitmq-cluster-server-2', 'uid': 'SIEVE-IGNORE'}, 'spec': {'accessModes': ['ReadWriteOnce'], 'resources': {'requests': {'storage': '10Gi'}}, 'storageClassName': 'standard', 'volumeMode': 'Filesystem'}, 'status': {'phase': 'Pending'}}  =>  not present
# not present
# 12233232 <class 'deepdiff.helper.NotPresent'>
# iterable_item_removed ['pod', 2, 'spec', 'volumes', 1] 2
# {'configMap': {'defaultMode': 420, 'name': 'rabbitmq-cluster-plugins-conf'}, 'name': 'plugins-conf'}
# iterable_item_removed pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'spec', 'volumes', 1] {'configMap': {'defaultMode': 420, 'name': 'rabbitmq-cluster-plugins-conf'}, 'name': 'plugins-conf'}  =>  not present
# not present
# 12233232 <class 'deepdiff.helper.NotPresent'>
# iterable_item_removed ['pod', 2, 'spec', 'volumes', 2] 2
# {'name': 'rabbitmq-confd', 'projected': {'defaultMode': 420, 'sources': [{'secret': {'items': [{'key': 'default_user.conf', 'path': 'default_user.conf'}], 'name': 'rabbitmq-cluster-default-user'}}, {'configMap': {'items': [{'key': 'operatorDefaults.conf', 'path': 'operatorDefaults.conf'}, {'key': 'userDefinedConfiguration.conf', 'path': 'userDefinedConfiguration.conf'}], 'name': 'rabbitmq-cluster-server-conf'}}]}}
# iterable_item_removed pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'spec', 'volumes', 2] {'name': 'rabbitmq-confd', 'projected': {'defaultMode': 420, 'sources': [{'secret': {'items': [{'key': 'default_user.conf', 'path': 'default_user.conf'}], 'name': 'rabbitmq-cluster-default-user'}}, {'configMap': {'items': [{'key': 'operatorDefaults.conf', 'path': 'operatorDefaults.conf'}, {'key': 'userDefinedConfiguration.conf', 'path': 'userDefinedConfiguration.conf'}], 'name': 'rabbitmq-cluster-server-conf'}}]}}  =>  not present
# not present
# 12233232 <class 'deepdiff.helper.NotPresent'>
# iterable_item_removed ['pod', 2, 'spec', 'volumes', 3] 2
# {'emptyDir': {}, 'name': 'rabbitmq-erlang-cookie'}
# iterable_item_removed pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'spec', 'volumes', 3] {'emptyDir': {}, 'name': 'rabbitmq-erlang-cookie'}  =>  not present
# not present
# 12233232 <class 'deepdiff.helper.NotPresent'>
# iterable_item_removed ['pod', 2, 'spec', 'volumes', 4] 2
# {'name': 'erlang-cookie-secret', 'secret': {'defaultMode': 420, 'secretName': 'rabbitmq-cluster-erlang-cookie'}}
# iterable_item_removed pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'spec', 'volumes', 4] {'name': 'erlang-cookie-secret', 'secret': {'defaultMode': 420, 'secretName': 'rabbitmq-cluster-erlang-cookie'}}  =>  not present
# not present
# 12233232 <class 'deepdiff.helper.NotPresent'>
# iterable_item_removed ['pod', 2, 'spec', 'volumes', 5] 2
# {'emptyDir': {}, 'name': 'rabbitmq-plugins'}
# iterable_item_removed pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'spec', 'volumes', 5] {'emptyDir': {}, 'name': 'rabbitmq-plugins'}  =>  not present
# not present
# 12233232 <class 'deepdiff.helper.NotPresent'>
# iterable_item_removed ['pod', 2, 'spec', 'volumes', 6] 2
# {'downwardAPI': {'defaultMode': 420, 'items': [{'fieldRef': {'apiVersion': 'v1', 'fieldPath': "metadata.labels['skipPreStopChecks']"}, 'path': 'skipPreStopChecks'}]}, 'name': 'pod-info'}
# iterable_item_removed pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'spec', 'volumes', 6] {'downwardAPI': {'defaultMode': 420, 'items': [{'fieldRef': {'apiVersion': 'v1', 'fieldPath': "metadata.labels['skipPreStopChecks']"}, 'path': 'skipPreStopChecks'}]}, 'name': 'pod-info'}  =>  not present
# not present
# 12233232 <class 'deepdiff.helper.NotPresent'>
# iterable_item_removed ['pod', 2, 'spec', 'volumes', 7] 2
# {'name': 'SIEVE-IGNORE', 'secret': {'defaultMode': 420, 'secretName': 'SIEVE-IGNORE'}}
# iterable_item_removed pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'spec', 'volumes', 7] {'name': 'SIEVE-IGNORE', 'secret': {'defaultMode': 420, 'secretName': 'SIEVE-IGNORE'}}  =>  not present
# not present
# 12233232 <class 'deepdiff.helper.NotPresent'>
# iterable_item_removed ['pod', 2, 'spec', 'containers', 0, 'ports', 1] 2
# {'containerPort': 5672, 'name': 'amqp', 'protocol': 'TCP'}
# iterable_item_removed pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'spec', 'containers', 0, 'ports', 1] {'containerPort': 5672, 'name': 'amqp', 'protocol': 'TCP'}  =>  not present
# not present
# 12233232 <class 'deepdiff.helper.NotPresent'>
# iterable_item_removed ['pod', 2, 'spec', 'containers', 0, 'ports', 2] 2
# {'containerPort': 15672, 'name': 'management', 'protocol': 'TCP'}
# iterable_item_removed pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'spec', 'containers', 0, 'ports', 2] {'containerPort': 15672, 'name': 'management', 'protocol': 'TCP'}  =>  not present
# not present
# 12233232 <class 'deepdiff.helper.NotPresent'>
# iterable_item_removed ['pod', 2, 'spec', 'containers', 0, 'ports', 3] 2
# {'containerPort': 15692, 'name': 'prometheus', 'protocol': 'TCP'}
# iterable_item_removed pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'spec', 'containers', 0, 'ports', 3] {'containerPort': 15692, 'name': 'prometheus', 'protocol': 'TCP'}  =>  not present
# not present
# 12233232 <class 'deepdiff.helper.NotPresent'>
# iterable_item_removed ['pod', 2, 'spec', 'containers', 0, 'env', 3] 2
# {'name': 'K8S_SERVICE_NAME', 'value': 'rabbitmq-cluster-nodes'}
# iterable_item_removed pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'spec', 'containers', 0, 'env', 3] {'name': 'K8S_SERVICE_NAME', 'value': 'rabbitmq-cluster-nodes'}  =>  not present
# not present
# 12233232 <class 'deepdiff.helper.NotPresent'>
# iterable_item_removed ['pod', 2, 'spec', 'containers', 0, 'env', 4] 2
# {'name': 'RABBITMQ_USE_LONGNAME', 'value': 'true'}
# iterable_item_removed pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'spec', 'containers', 0, 'env', 4] {'name': 'RABBITMQ_USE_LONGNAME', 'value': 'true'}  =>  not present
# not present
# 12233232 <class 'deepdiff.helper.NotPresent'>
# iterable_item_removed ['pod', 2, 'spec', 'containers', 0, 'env', 5] 2
# {'name': 'RABBITMQ_NODENAME', 'value': 'rabbit@$(MY_POD_NAME).$(K8S_SERVICE_NAME).$(MY_POD_NAMESPACE)'}
# iterable_item_removed pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'spec', 'containers', 0, 'env', 5] {'name': 'RABBITMQ_NODENAME', 'value': 'rabbit@$(MY_POD_NAME).$(K8S_SERVICE_NAME).$(MY_POD_NAMESPACE)'}  =>  not present
# not present
# 12233232 <class 'deepdiff.helper.NotPresent'>
# iterable_item_removed ['pod', 2, 'spec', 'containers', 0, 'env', 6] 2
# {'name': 'K8S_HOSTNAME_SUFFIX', 'value': '.$(K8S_SERVICE_NAME).$(MY_POD_NAMESPACE)'}
# iterable_item_removed pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'spec', 'containers', 0, 'env', 6] {'name': 'K8S_HOSTNAME_SUFFIX', 'value': '.$(K8S_SERVICE_NAME).$(MY_POD_NAMESPACE)'}  =>  not present
# not present
# 12233232 <class 'deepdiff.helper.NotPresent'>
# iterable_item_removed ['pod', 2, 'spec', 'containers', 0, 'volumeMounts', 1] 2
# {'mountPath': '/var/lib/rabbitmq/mnesia/', 'name': 'persistence'}
# iterable_item_removed pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'spec', 'containers', 0, 'volumeMounts', 1] {'mountPath': '/var/lib/rabbitmq/mnesia/', 'name': 'persistence'}  =>  not present
# not present
# 12233232 <class 'deepdiff.helper.NotPresent'>
# iterable_item_removed ['pod', 2, 'spec', 'containers', 0, 'volumeMounts', 2] 2
# {'mountPath': '/operator', 'name': 'rabbitmq-plugins'}
# iterable_item_removed pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'spec', 'containers', 0, 'volumeMounts', 2] {'mountPath': '/operator', 'name': 'rabbitmq-plugins'}  =>  not present
# not present
# 12233232 <class 'deepdiff.helper.NotPresent'>
# iterable_item_removed ['pod', 2, 'spec', 'containers', 0, 'volumeMounts', 3] 2
# {'mountPath': '/etc/rabbitmq/conf.d/10-operatorDefaults.conf', 'name': 'rabbitmq-confd', 'subPath': 'operatorDefaults.conf'}
# iterable_item_removed pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'spec', 'containers', 0, 'volumeMounts', 3] {'mountPath': '/etc/rabbitmq/conf.d/10-operatorDefaults.conf', 'name': 'rabbitmq-confd', 'subPath': 'operatorDefaults.conf'}  =>  not present
# not present
# 12233232 <class 'deepdiff.helper.NotPresent'>
# iterable_item_removed ['pod', 2, 'spec', 'containers', 0, 'volumeMounts', 4] 2
# {'mountPath': '/etc/rabbitmq/conf.d/11-default_user.conf', 'name': 'rabbitmq-confd', 'subPath': 'default_user.conf'}
# iterable_item_removed pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'spec', 'containers', 0, 'volumeMounts', 4] {'mountPath': '/etc/rabbitmq/conf.d/11-default_user.conf', 'name': 'rabbitmq-confd', 'subPath': 'default_user.conf'}  =>  not present
# not present
# 12233232 <class 'deepdiff.helper.NotPresent'>
# iterable_item_removed ['pod', 2, 'spec', 'containers', 0, 'volumeMounts', 5] 2
# {'mountPath': '/etc/rabbitmq/conf.d/90-userDefinedConfiguration.conf', 'name': 'rabbitmq-confd', 'subPath': 'userDefinedConfiguration.conf'}
# iterable_item_removed pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'spec', 'containers', 0, 'volumeMounts', 5] {'mountPath': '/etc/rabbitmq/conf.d/90-userDefinedConfiguration.conf', 'name': 'rabbitmq-confd', 'subPath': 'userDefinedConfiguration.conf'}  =>  not present
# not present
# 12233232 <class 'deepdiff.helper.NotPresent'>
# iterable_item_removed ['pod', 2, 'spec', 'containers', 0, 'volumeMounts', 6] 2
# {'mountPath': '/etc/pod-info/', 'name': 'pod-info'}
# iterable_item_removed pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'spec', 'containers', 0, 'volumeMounts', 6] {'mountPath': '/etc/pod-info/', 'name': 'pod-info'}  =>  not present
# not present
# 12233232 <class 'deepdiff.helper.NotPresent'>
# iterable_item_removed ['pod', 2, 'spec', 'containers', 0, 'volumeMounts', 7] 2
# {'mountPath': '/var/run/secrets/kubernetes.io/serviceaccount', 'name': 'SIEVE-IGNORE', 'readOnly': True}
# iterable_item_removed pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'spec', 'containers', 0, 'volumeMounts', 7] {'mountPath': '/var/run/secrets/kubernetes.io/serviceaccount', 'name': 'SIEVE-IGNORE', 'readOnly': True}  =>  not present
# not present
# 12233232 <class 'deepdiff.helper.NotPresent'>
# iterable_item_removed ['pod', 3] 2
# {'metadata': {'creationTimestamp': 'SIEVE-IGNORE', 'generateName': 'rabbitmq-operator-b7d5945b-', 'labels': {'app.kubernetes.io/component': 'rabbitmq-cluster-operator', 'app.kubernetes.io/name': 'rabbitmq-cluster-operator', 'app.kubernetes.io/part-of': 'rabbitmq', 'pod-template-hash': 'b7d5945b', 'sievetag': 'rabbitmq-operator'}, 'managedFields': [{'apiVersion': 'v1', 'fieldsType': 'FieldsV1', 'fieldsV1': {'f:metadata': {'f:generateName': {}, 'f:labels': {'.': {}, 'f:app.kubernetes.io/component': {}, 'f:app.kubernetes.io/name': {}, 'f:app.kubernetes.io/part-of': {}, 'f:pod-template-hash': {}, 'f:sievetag': {}}, 'f:ownerReferences': {'.': {}, 'k:{"uid":"2b4100bc-10ae-4e57-a99f-9b676b826c8c"}': 'SIEVE-IGNORE'}}, 'f:spec': {'f:containers': {'k:{"name":"operator"}': {'.': {}, 'f:command': {}, 'f:env': {'.': {}, 'k:{"name":"KUBERNETES_SERVICE_HOST"}': {'.': {}, 'f:name': {}, 'f:value': {}}, 'k:{"name":"KUBERNETES_SERVICE_PORT"}': {'.': {}, 'f:name': {}, 'f:value': {}}, 'k:{"name":"OPERATOR_NAMESPACE"}': {'.': {}, 'f:name': {}, 'f:valueFrom': {'.': {}, 'f:fieldRef': {'.': {}, 'f:apiVersion': {}, 'f:fieldPath': {}}}}}, 'f:envFrom': {}, 'f:image': {}, 'f:imagePullPolicy': {}, 'f:name': {}, 'f:ports': {'.': {}, 'k:{"containerPort":9782,"protocol":"TCP"}': {'.': {}, 'f:containerPort': {}, 'f:name': {}, 'f:protocol': {}}}, 'f:resources': {'.': {}, 'f:limits': {'.': {}, 'f:cpu': {}, 'f:memory': {}}, 'f:requests': {'.': {}, 'f:cpu': {}, 'f:memory': {}}}, 'f:terminationMessagePath': {}, 'f:terminationMessagePolicy': {}}}, 'f:dnsPolicy': {}, 'f:enableServiceLinks': {}, 'f:restartPolicy': {}, 'f:schedulerName': {}, 'f:securityContext': {'.': {}, 'f:fsGroup': {}, 'f:runAsGroup': {}, 'f:runAsUser': {}}, 'f:serviceAccount': {}, 'f:serviceAccountName': {}, 'f:terminationGracePeriodSeconds': {}}}, 'manager': 'kube-controller-manager', 'operation': 'Update', 'time': 'SIEVE-IGNORE'}, {'apiVersion': 'v1', 'fieldsType': 'FieldsV1', 'fieldsV1': {'f:status': {'f:conditions': {'.': {}, 'k:{"type":"PodScheduled"}': {'.': {}, 'f:lastProbeTime': {}, 'f:lastTransitionTime': {}, 'f:message': {}, 'f:reason': {}, 'f:status': {}, 'f:type': {}}}}}, 'manager': 'kube-scheduler', 'operation': 'Update', 'time': 'SIEVE-IGNORE'}, {'apiVersion': 'v1', 'fieldsType': 'FieldsV1', 'fieldsV1': {'f:status': {'f:conditions': {'k:{"type":"ContainersReady"}': {'.': {}, 'f:lastProbeTime': {}, 'f:lastTransitionTime': {}, 'f:status': {}, 'f:type': {}}, 'k:{"type":"Initialized"}': {'.': {}, 'f:lastProbeTime': {}, 'f:lastTransitionTime': {}, 'f:status': {}, 'f:type': {}}, 'k:{"type":"Ready"}': {'.': {}, 'f:lastProbeTime': {}, 'f:lastTransitionTime': {}, 'f:status': {}, 'f:type': {}}}, 'f:containerStatuses': {}, 'f:hostIP': {}, 'f:phase': {}, 'f:podIP': {}, 'f:podIPs': {'.': {}, 'k:{"ip":"10.244.1.2"}': 'SIEVE-IGNORE'}, 'f:startTime': {}}}, 'manager': 'kubelet', 'operation': 'Update', 'time': 'SIEVE-IGNORE'}], 'name': 'SIEVE-IGNORE', 'namespace': 'default', 'ownerReferences': [{'apiVersion': 'apps/v1', 'blockOwnerDeletion': True, 'controller': True, 'kind': 'ReplicaSet', 'name': 'rabbitmq-operator-b7d5945b', 'uid': 'SIEVE-IGNORE'}], 'resourceVersion': 'SIEVE-IGNORE', 'selfLink': 'SIEVE-IGNORE', 'uid': 'SIEVE-IGNORE'}, 'spec': {'containers': [{'command': ['/manager'], 'env': [{'name': 'OPERATOR_NAMESPACE', 'valueFrom': {'fieldRef': {'apiVersion': 'v1', 'fieldPath': 'metadata.namespace'}}}, {'name': 'KUBERNETES_SERVICE_HOST', 'value': 'kind-control-plane'}, {'name': 'KUBERNETES_SERVICE_PORT', 'value': '6443'}], 'envFrom': [{'configMapRef': {'name': 'sieve-testing-global-config'}}], 'image': 'ghcr.io/sieve-project/action/rabbitmq-operator:learn', 'imagePullPolicy': 'IfNotPresent', 'name': 'operator', 'ports': [{'containerPort': 9782, 'name': 'metrics', 'protocol': 'TCP'}], 'resources': {'limits': {'cpu': '200m', 'memory': '500Mi'}, 'requests': {'cpu': '200m', 'memory': '500Mi'}}, 'terminationMessagePath': '/dev/termination-log', 'terminationMessagePolicy': 'File', 'volumeMounts': [{'moun ...
# iterable_item_removed pod default SIEVE-IGNORE ['pod', 3] {'metadata': {'creationTimestamp': 'SIEVE-IGNORE', 'generateName': 'rabbitmq-operator-b7d5945b-', 'labels': {'app.kubernetes.io/component': 'rabbitmq-cluster-operator', 'app.kubernetes.io/name': 'rabbitmq-cluster-operator', 'app.kubernetes.io/part-of': 'rabbitmq', 'pod-template-hash': 'b7d5945b', 'sievetag': 'rabbitmq-operator'}, 'managedFields': [{'apiVersion': 'v1', 'fieldsType': 'FieldsV1', 'fieldsV1': {'f:metadata': {'f:generateName': {}, 'f:labels': {'.': {}, 'f:app.kubernetes.io/component': {}, 'f:app.kubernetes.io/name': {}, 'f:app.kubernetes.io/part-of': {}, 'f:pod-template-hash': {}, 'f:sievetag': {}}, 'f:ownerReferences': {'.': {}, 'k:{"uid":"2b4100bc-10ae-4e57-a99f-9b676b826c8c"}': 'SIEVE-IGNORE'}}, 'f:spec': {'f:containers': {'k:{"name":"operator"}': {'.': {}, 'f:command': {}, 'f:env': {'.': {}, 'k:{"name":"KUBERNETES_SERVICE_HOST"}': {'.': {}, 'f:name': {}, 'f:value': {}}, 'k:{"name":"KUBERNETES_SERVICE_PORT"}': {'.': {}, 'f:name': {}, 'f:value': {}}, 'k:{"name":"OPERATOR_NAMESPACE"}': {'.': {}, 'f:name': {}, 'f:valueFrom': {'.': {}, 'f:fieldRef': {'.': {}, 'f:apiVersion': {}, 'f:fieldPath': {}}}}}, 'f:envFrom': {}, 'f:image': {}, 'f:imagePullPolicy': {}, 'f:name': {}, 'f:ports': {'.': {}, 'k:{"containerPort":9782,"protocol":"TCP"}': {'.': {}, 'f:containerPort': {}, 'f:name': {}, 'f:protocol': {}}}, 'f:resources': {'.': {}, 'f:limits': {'.': {}, 'f:cpu': {}, 'f:memory': {}}, 'f:requests': {'.': {}, 'f:cpu': {}, 'f:memory': {}}}, 'f:terminationMessagePath': {}, 'f:terminationMessagePolicy': {}}}, 'f:dnsPolicy': {}, 'f:enableServiceLinks': {}, 'f:restartPolicy': {}, 'f:schedulerName': {}, 'f:securityContext': {'.': {}, 'f:fsGroup': {}, 'f:runAsGroup': {}, 'f:runAsUser': {}}, 'f:serviceAccount': {}, 'f:serviceAccountName': {}, 'f:terminationGracePeriodSeconds': {}}}, 'manager': 'kube-controller-manager', 'operation': 'Update', 'time': 'SIEVE-IGNORE'}, {'apiVersion': 'v1', 'fieldsType': 'FieldsV1', 'fieldsV1': {'f:status': {'f:conditions': {'.': {}, 'k:{"type":"PodScheduled"}': {'.': {}, 'f:lastProbeTime': {}, 'f:lastTransitionTime': {}, 'f:message': {}, 'f:reason': {}, 'f:status': {}, 'f:type': {}}}}}, 'manager': 'kube-scheduler', 'operation': 'Update', 'time': 'SIEVE-IGNORE'}, {'apiVersion': 'v1', 'fieldsType': 'FieldsV1', 'fieldsV1': {'f:status': {'f:conditions': {'k:{"type":"ContainersReady"}': {'.': {}, 'f:lastProbeTime': {}, 'f:lastTransitionTime': {}, 'f:status': {}, 'f:type': {}}, 'k:{"type":"Initialized"}': {'.': {}, 'f:lastProbeTime': {}, 'f:lastTransitionTime': {}, 'f:status': {}, 'f:type': {}}, 'k:{"type":"Ready"}': {'.': {}, 'f:lastProbeTime': {}, 'f:lastTransitionTime': {}, 'f:status': {}, 'f:type': {}}}, 'f:containerStatuses': {}, 'f:hostIP': {}, 'f:phase': {}, 'f:podIP': {}, 'f:podIPs': {'.': {}, 'k:{"ip":"10.244.1.2"}': 'SIEVE-IGNORE'}, 'f:startTime': {}}}, 'manager': 'kubelet', 'operation': 'Update', 'time': 'SIEVE-IGNORE'}], 'name': 'SIEVE-IGNORE', 'namespace': 'default', 'ownerReferences': [{'apiVersion': 'apps/v1', 'blockOwnerDeletion': True, 'controller': True, 'kind': 'ReplicaSet', 'name': 'rabbitmq-operator-b7d5945b', 'uid': 'SIEVE-IGNORE'}], 'resourceVersion': 'SIEVE-IGNORE', 'selfLink': 'SIEVE-IGNORE', 'uid': 'SIEVE-IGNORE'}, 'spec': {'containers': [{'command': ['/manager'], 'env': [{'name': 'OPERATOR_NAMESPACE', 'valueFrom': {'fieldRef': {'apiVersion': 'v1', 'fieldPath': 'metadata.namespace'}}}, {'name': 'KUBERNETES_SERVICE_HOST', 'value': 'kind-control-plane'}, {'name': 'KUBERNETES_SERVICE_PORT', 'value': '6443'}], 'envFrom': [{'configMapRef': {'name': 'sieve-testing-global-config'}}], 'image': 'ghcr.io/sieve-project/action/rabbitmq-operator:learn', 'imagePullPolicy': 'IfNotPresent', 'name': 'operator', 'ports': [{'containerPort': 9782, 'name': 'metrics', 'protocol': 'TCP'}], 'resources': {'limits': {'cpu': '200m', 'memory': '500Mi'}, 'requests': {'cpu': '200m', 'memory': '500Mi'}}, 'terminationMessagePath': '/dev/termination-log', ' ...
# {'secretName': 'rabbitmq-cluster-operator-token-s4tkc', 'defaultMode': 420}
# dictionary_item_added ['pod', 2, 'spec', 'volumes', 0, 'secret'] 2
# not present
# dictionary_item_added pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'spec', 'volumes', 0, 'secret'] not present  =>  {'secretName': 'rabbitmq-cluster-operator-token-s4tkc', 'defaultMode': 420}
# ['/manager']
# dictionary_item_added ['pod', 2, 'spec', 'containers', 0, 'command'] 2
# not present
# dictionary_item_added pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'spec', 'containers', 0, 'command'] not present  =>  ['/manager']
# [{'configMapRef': {'name': 'sieve-testing-global-config'}}]
# dictionary_item_added ['pod', 2, 'spec', 'containers', 0, 'envFrom'] 2
# not present
# dictionary_item_added pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'spec', 'containers', 0, 'envFrom'] not present  =>  [{'configMapRef': {'name': 'sieve-testing-global-config'}}]
# kind-control-plane
# dictionary_item_added ['pod', 2, 'spec', 'containers', 0, 'env', 1, 'value'] 2
# not present
# dictionary_item_added pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'spec', 'containers', 0, 'env', 1, 'value'] not present  =>  kind-control-plane
# True
# dictionary_item_added ['pod', 2, 'spec', 'containers', 0, 'volumeMounts', 0, 'readOnly'] 2
# not present
# dictionary_item_added pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'spec', 'containers', 0, 'volumeMounts', 0, 'readOnly'] not present  =>  True
# 10.244.2.2
# dictionary_item_added ['pod', 2, 'status', 'podIP'] 2
# not present
# dictionary_item_added pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'status', 'podIP'] not present  =>  10.244.2.2
# [{'ip': '10.244.2.2'}]
# dictionary_item_added ['pod', 2, 'status', 'podIPs'] 2
# not present
# dictionary_item_added pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'status', 'podIPs'] not present  =>  [{'ip': '10.244.2.2'}]
# 2021-09-15T03:56:01Z
# dictionary_item_added ['pod', 2, 'status', 'startTime'] 2
# not present
# dictionary_item_added pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'status', 'startTime'] not present  =>  2021-09-15T03:56:01Z
# [{'name': 'operator', 'state': {'running': {'startedAt': '2021-09-15T03:56:02Z'}}, 'lastState': {}, 'ready': True, 'restartCount': 0, 'image': 'ghcr.io/sieve-project/action/rabbitmq-operator:observability-gap', 'imageID': 'sha256:88140935aaa3b52e75e57d9a63d58c56002e52eef1344819bf6b63c2e653e622', 'containerID': 'containerd://8428b97f6c618d7fe6b109af22d65a5995a97b2ebc2f4153dc113d48a9997ee9', 'started': True}]
# dictionary_item_added ['pod', 2, 'status', 'containerStatuses'] 2
# not present
# dictionary_item_added pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'status', 'containerStatuses'] not present  =>  [{'name': 'operator', 'state': {'running': {'startedAt': '2021-09-15T03:56:02Z'}}, 'lastState': {}, 'ready': True, 'restartCount': 0, 'image': 'ghcr.io/sieve-project/action/rabbitmq-operator:observability-gap', 'imageID': 'sha256:88140935aaa3b52e75e57d9a63d58c56002e52eef1344819bf6b63c2e653e622', 'containerID': 'containerd://8428b97f6c618d7fe6b109af22d65a5995a97b2ebc2f4153dc113d48a9997ee9', 'started': True}]
# {"spec": {"replicas": 3}}
# dictionary_item_added ['configmap', 3, 'data', 'SIEVE-CE-DIFF-CURRENT'] 2
# not present
# dictionary_item_added configmap default sieve-testing-global-config ['configmap', 3, 'data', 'SIEVE-CE-DIFF-CURRENT'] not present  =>  {"spec": {"replicas": 3}}
# {"spec": {"replicas": 1}}
# dictionary_item_added ['configmap', 3, 'data', 'SIEVE-CE-DIFF-PREVIOUS'] 2
# not present
# dictionary_item_added configmap default sieve-testing-global-config ['configmap', 3, 'data', 'SIEVE-CE-DIFF-PREVIOUS'] not present  =>  {"spec": {"replicas": 1}}
# Updated
# dictionary_item_added ['configmap', 3, 'data', 'SIEVE-CE-ETYPE-CURRENT'] 2
# not present
# dictionary_item_added configmap default sieve-testing-global-config ['configmap', 3, 'data', 'SIEVE-CE-ETYPE-CURRENT'] not present  =>  Updated
# Updated
# dictionary_item_added ['configmap', 3, 'data', 'SIEVE-CE-ETYPE-PREVIOUS'] 2
# not present
# dictionary_item_added configmap default sieve-testing-global-config ['configmap', 3, 'data', 'SIEVE-CE-ETYPE-PREVIOUS'] not present  =>  Updated
# rabbitmq-cluster
# dictionary_item_added ['configmap', 3, 'data', 'SIEVE-CE-NAME'] 2
# not present
# dictionary_item_added configmap default sieve-testing-global-config ['configmap', 3, 'data', 'SIEVE-CE-NAME'] not present  =>  rabbitmq-cluster
# default
# dictionary_item_added ['configmap', 3, 'data', 'SIEVE-CE-NAMESPACE'] 2
# not present
# dictionary_item_added configmap default sieve-testing-global-config ['configmap', 3, 'data', 'SIEVE-CE-NAMESPACE'] not present  =>  default
# rabbitmqcluster
# dictionary_item_added ['configmap', 3, 'data', 'SIEVE-CE-RTYPE'] 2
# not present
# dictionary_item_added configmap default sieve-testing-global-config ['configmap', 3, 'data', 'SIEVE-CE-RTYPE'] not present  =>  rabbitmqcluster
# rabbitmq-operator
# dictionary_item_added ['configmap', 3, 'data', 'SIEVE-OPERATOR-POD-LABEL'] 2
# not present
# dictionary_item_added configmap default sieve-testing-global-config ['configmap', 3, 'data', 'SIEVE-OPERATOR-POD-LABEL'] not present  =>  rabbitmq-operator
# rabbitmq-operator
# dictionary_item_added ['configmap', 3, 'data', 'SIEVE-PROJECT'] 2
# not present
# dictionary_item_added configmap default sieve-testing-global-config ['configmap', 3, 'data', 'SIEVE-PROJECT'] not present  =>  rabbitmq-operator
# not present
# 12233232 <class 'deepdiff.helper.NotPresent'>
# dictionary_item_removed ['pod', 2, 'spec', 'automountServiceAccountToken'] 2
# True
# dictionary_item_removed pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'spec', 'automountServiceAccountToken'] True  =>  not present
# not present
# 12233232 <class 'deepdiff.helper.NotPresent'>
# dictionary_item_removed ['pod', 2, 'spec', 'hostname'] 2
# rabbitmq-cluster-server-2
# dictionary_item_removed pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'spec', 'hostname'] rabbitmq-cluster-server-2  =>  not present
# not present
# 12233232 <class 'deepdiff.helper.NotPresent'>
# dictionary_item_removed ['pod', 2, 'spec', 'initContainers'] 2
# [{'command': ['sh', '-c', "cp /tmp/erlang-cookie-secret/.erlang.cookie /var/lib/rabbitmq/.erlang.cookie && chown 999:999 /var/lib/rabbitmq/.erlang.cookie && chmod 600 /var/lib/rabbitmq/.erlang.cookie ; cp /tmp/rabbitmq-plugins/enabled_plugins /operator/enabled_plugins && chown 999:999 /operator/enabled_plugins ; chown 999:999 /var/lib/rabbitmq/mnesia/ ; echo '[default]' > /var/lib/rabbitmq/.rabbitmqadmin.conf && sed -e 's/default_user/username/' -e 's/default_pass/password/' /tmp/default_user.conf >> /var/lib/rabbitmq/.rabbitmqadmin.conf && chown 999:999 /var/lib/rabbitmq/.rabbitmqadmin.conf && chmod 600 /var/lib/rabbitmq/.rabbitmqadmin.conf"], 'image': 'rabbitmq:3.8.12-management', 'imagePullPolicy': 'IfNotPresent', 'name': 'setup-container', 'resources': {'limits': {'cpu': '100m', 'memory': '500Mi'}, 'requests': {'cpu': '100m', 'memory': '500Mi'}}, 'securityContext': {'capabilities': {'drop': ['FSETID', 'KILL', 'SETGID', 'SETUID', 'SETPCAP', 'NET_BIND_SERVICE', 'NET_RAW', 'SYS_CHROOT', 'MKNOD', 'AUDIT_WRITE', 'SETFCAP']}, 'runAsUser': 0}, 'terminationMessagePath': '/dev/termination-log', 'terminationMessagePolicy': 'File', 'volumeMounts': [{'mountPath': '/tmp/rabbitmq-plugins/', 'name': 'plugins-conf'}, {'mountPath': '/var/lib/rabbitmq/', 'name': 'rabbitmq-erlang-cookie'}, {'mountPath': '/tmp/erlang-cookie-secret/', 'name': 'erlang-cookie-secret'}, {'mountPath': '/operator', 'name': 'rabbitmq-plugins'}, {'mountPath': '/var/lib/rabbitmq/mnesia/', 'name': 'persistence'}, {'mountPath': '/tmp/default_user.conf', 'name': 'rabbitmq-confd', 'subPath': 'default_user.conf'}, {'mountPath': '/var/run/secrets/kubernetes.io/serviceaccount', 'name': 'SIEVE-IGNORE', 'readOnly': True}]}]
# dictionary_item_removed pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'spec', 'initContainers'] [{'command': ['sh', '-c', "cp /tmp/erlang-cookie-secret/.erlang.cookie /var/lib/rabbitmq/.erlang.cookie && chown 999:999 /var/lib/rabbitmq/.erlang.cookie && chmod 600 /var/lib/rabbitmq/.erlang.cookie ; cp /tmp/rabbitmq-plugins/enabled_plugins /operator/enabled_plugins && chown 999:999 /operator/enabled_plugins ; chown 999:999 /var/lib/rabbitmq/mnesia/ ; echo '[default]' > /var/lib/rabbitmq/.rabbitmqadmin.conf && sed -e 's/default_user/username/' -e 's/default_pass/password/' /tmp/default_user.conf >> /var/lib/rabbitmq/.rabbitmqadmin.conf && chown 999:999 /var/lib/rabbitmq/.rabbitmqadmin.conf && chmod 600 /var/lib/rabbitmq/.rabbitmqadmin.conf"], 'image': 'rabbitmq:3.8.12-management', 'imagePullPolicy': 'IfNotPresent', 'name': 'setup-container', 'resources': {'limits': {'cpu': '100m', 'memory': '500Mi'}, 'requests': {'cpu': '100m', 'memory': '500Mi'}}, 'securityContext': {'capabilities': {'drop': ['FSETID', 'KILL', 'SETGID', 'SETUID', 'SETPCAP', 'NET_BIND_SERVICE', 'NET_RAW', 'SYS_CHROOT', 'MKNOD', 'AUDIT_WRITE', 'SETFCAP']}, 'runAsUser': 0}, 'terminationMessagePath': '/dev/termination-log', 'terminationMessagePolicy': 'File', 'volumeMounts': [{'mountPath': '/tmp/rabbitmq-plugins/', 'name': 'plugins-conf'}, {'mountPath': '/var/lib/rabbitmq/', 'name': 'rabbitmq-erlang-cookie'}, {'mountPath': '/tmp/erlang-cookie-secret/', 'name': 'erlang-cookie-secret'}, {'mountPath': '/operator', 'name': 'rabbitmq-plugins'}, {'mountPath': '/var/lib/rabbitmq/mnesia/', 'name': 'persistence'}, {'mountPath': '/tmp/default_user.conf', 'name': 'rabbitmq-confd', 'subPath': 'default_user.conf'}, {'mountPath': '/var/run/secrets/kubernetes.io/serviceaccount', 'name': 'SIEVE-IGNORE', 'readOnly': True}]}]  =>  not present
# not present
# 12233232 <class 'deepdiff.helper.NotPresent'>
# dictionary_item_removed ['pod', 2, 'spec', 'subdomain'] 2
# rabbitmq-cluster-nodes
# dictionary_item_removed pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'spec', 'subdomain'] rabbitmq-cluster-nodes  =>  not present
# not present
# 12233232 <class 'deepdiff.helper.NotPresent'>
# dictionary_item_removed ['pod', 2, 'spec', 'topologySpreadConstraints'] 2
# [{'labelSelector': {'matchLabels': {'app.kubernetes.io/name': 'rabbitmq-cluster'}}, 'maxSkew': 1, 'topologyKey': 'topology.kubernetes.io/zone', 'whenUnsatisfiable': 'ScheduleAnyway'}]
# dictionary_item_removed pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'spec', 'topologySpreadConstraints'] [{'labelSelector': {'matchLabels': {'app.kubernetes.io/name': 'rabbitmq-cluster'}}, 'maxSkew': 1, 'topologyKey': 'topology.kubernetes.io/zone', 'whenUnsatisfiable': 'ScheduleAnyway'}]  =>  not present
# not present
# 12233232 <class 'deepdiff.helper.NotPresent'>
# dictionary_item_removed ['pod', 2, 'spec', 'volumes', 0, 'persistentVolumeClaim'] 2
# {'claimName': 'persistence-rabbitmq-cluster-server-2'}
# dictionary_item_removed pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'spec', 'volumes', 0, 'persistentVolumeClaim'] {'claimName': 'persistence-rabbitmq-cluster-server-2'}  =>  not present
# not present
# 12233232 <class 'deepdiff.helper.NotPresent'>
# dictionary_item_removed ['pod', 2, 'spec', 'containers', 0, 'lifecycle'] 2
# {'preStop': {'exec': {'command': ['/bin/bash', '-c', 'if [ ! -z "$(cat /etc/pod-info/skipPreStopChecks)" ]; then exit 0; fi; rabbitmq-upgrade await_online_quorum_plus_one -t 604800; rabbitmq-upgrade await_online_synchronized_mirror -t 604800; rabbitmq-upgrade drain -t 604800']}}}
# dictionary_item_removed pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'spec', 'containers', 0, 'lifecycle'] {'preStop': {'exec': {'command': ['/bin/bash', '-c', 'if [ ! -z "$(cat /etc/pod-info/skipPreStopChecks)" ]; then exit 0; fi; rabbitmq-upgrade await_online_quorum_plus_one -t 604800; rabbitmq-upgrade await_online_synchronized_mirror -t 604800; rabbitmq-upgrade drain -t 604800']}}}  =>  not present
# not present
# 12233232 <class 'deepdiff.helper.NotPresent'>
# dictionary_item_removed ['pod', 2, 'spec', 'containers', 0, 'readinessProbe'] 2
# {'failureThreshold': 3, 'initialDelaySeconds': 10, 'periodSeconds': 10, 'successThreshold': 1, 'tcpSocket': {'port': 'amqp'}, 'timeoutSeconds': 5}
# dictionary_item_removed pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'spec', 'containers', 0, 'readinessProbe'] {'failureThreshold': 3, 'initialDelaySeconds': 10, 'periodSeconds': 10, 'successThreshold': 1, 'tcpSocket': {'port': 'amqp'}, 'timeoutSeconds': 5}  =>  not present
# not present
# 12233232 <class 'deepdiff.helper.NotPresent'>
# dictionary_item_removed ['pod', 2, 'spec', 'containers', 0, 'env', 1, 'valueFrom'] 2
# {'fieldRef': {'apiVersion': 'v1', 'fieldPath': 'metadata.namespace'}}
# dictionary_item_removed pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'spec', 'containers', 0, 'env', 1, 'valueFrom'] {'fieldRef': {'apiVersion': 'v1', 'fieldPath': 'metadata.namespace'}}  =>  not present
# not present
# 12233232 <class 'deepdiff.helper.NotPresent'>
# dictionary_item_removed ['pod', 2, 'status', 'conditions', 0, 'reason'] 2
# Unschedulable
# dictionary_item_removed pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'status', 'conditions', 0, 'reason'] Unschedulable  =>  not present
# not present
# 12233232 <class 'deepdiff.helper.NotPresent'>
# dictionary_item_removed ['configmap', 3, 'data', 'SIEVE-CRD-LIST'] 2
# rabbitmqcluster
# dictionary_item_removed configmap default sieve-testing-global-config ['configmap', 3, 'data', 'SIEVE-CRD-LIST'] rabbitmqcluster  =>  not present
# not present
# 12233232 <class 'deepdiff.helper.NotPresent'>
# dictionary_item_removed ['configmap', 3, 'data', 'SIEVE-RATE-LIMITER-ENABLED'] 2
# false
# dictionary_item_removed configmap default sieve-testing-global-config ['configmap', 3, 'data', 'SIEVE-RATE-LIMITER-ENABLED'] false  =>  not present
# not present
# 12233232 <class 'deepdiff.helper.NotPresent'>
# dictionary_item_removed ['configmap', 3, 'data', 'SIEVE-RATE-LIMITER-INTERVAL'] 2
# 3
# dictionary_item_removed configmap default sieve-testing-global-config ['configmap', 3, 'data', 'SIEVE-RATE-LIMITER-INTERVAL'] 3  =>  not present
# {'type': 'Ready', 'status': 'True', 'lastProbeTime': None, 'lastTransitionTime': '2021-09-15T03:56:03Z'}
# iterable_item_added ['pod', 2, 'status', 'conditions', 1] 2
# not present
# iterable_item_added pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'status', 'conditions', 1] not present  =>  {'type': 'Ready', 'status': 'True', 'lastProbeTime': None, 'lastTransitionTime': '2021-09-15T03:56:03Z'}
# {'type': 'ContainersReady', 'status': 'True', 'lastProbeTime': None, 'lastTransitionTime': '2021-09-15T03:56:03Z'}
# iterable_item_added ['pod', 2, 'status', 'conditions', 2] 2
# not present
# iterable_item_added pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'status', 'conditions', 2] not present  =>  {'type': 'ContainersReady', 'status': 'True', 'lastProbeTime': None, 'lastTransitionTime': '2021-09-15T03:56:03Z'}
# {'type': 'PodScheduled', 'status': 'True', 'lastProbeTime': None, 'lastTransitionTime': '2021-09-15T03:56:01Z'}
# iterable_item_added ['pod', 2, 'status', 'conditions', 3] 2
# not present
# iterable_item_added pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'status', 'conditions', 3] not present  =>  {'type': 'PodScheduled', 'status': 'True', 'lastProbeTime': None, 'lastTransitionTime': '2021-09-15T03:56:01Z'}
# rabbitmq-operator-54d7687666-hxvfz
# values_changed ['pod', 2, 'metadata', 'name'] 2
# rabbitmq-cluster-server-2
# values_changed pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'metadata', 'name'] rabbitmq-cluster-server-2  =>  rabbitmq-operator-54d7687666-hxvfz
# /api/v1/namespaces/default/pods/rabbitmq-operator-54d7687666-hxvfz
# values_changed ['pod', 2, 'metadata', 'selfLink'] 2
# /api/v1/namespaces/default/pods/rabbitmq-cluster-server-2
# values_changed pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'metadata', 'selfLink'] /api/v1/namespaces/default/pods/rabbitmq-cluster-server-2  =>  /api/v1/namespaces/default/pods/rabbitmq-operator-54d7687666-hxvfz
# rabbitmq-cluster-operator-token-s4tkc
# values_changed ['pod', 2, 'spec', 'volumes', 0, 'name'] 2
# persistence
# values_changed pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'spec', 'volumes', 0, 'name'] persistence  =>  rabbitmq-cluster-operator-token-s4tkc
# operator
# values_changed ['pod', 2, 'spec', 'containers', 0, 'name'] 2
# rabbitmq
# values_changed pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'spec', 'containers', 0, 'name'] rabbitmq  =>  operator
# metrics
# values_changed ['pod', 2, 'spec', 'containers', 0, 'ports', 0, 'name'] 2
# epmd
# values_changed pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'spec', 'containers', 0, 'ports', 0, 'name'] epmd  =>  metrics
# 9782
# values_changed ['pod', 2, 'spec', 'containers', 0, 'ports', 0, 'containerPort'] 2
# 4369
# values_changed pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'spec', 'containers', 0, 'ports', 0, 'containerPort'] 4369  =>  9782
# OPERATOR_NAMESPACE
# values_changed ['pod', 2, 'spec', 'containers', 0, 'env', 0, 'name'] 2
# MY_POD_NAME
# values_changed pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'spec', 'containers', 0, 'env', 0, 'name'] MY_POD_NAME  =>  OPERATOR_NAMESPACE
# metadata.namespace
# values_changed ['pod', 2, 'spec', 'containers', 0, 'env', 0, 'valueFrom', 'fieldRef', 'fieldPath'] 2
# metadata.name
# values_changed pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'spec', 'containers', 0, 'env', 0, 'valueFrom', 'fieldRef', 'fieldPath'] metadata.name  =>  metadata.namespace
# KUBERNETES_SERVICE_HOST
# values_changed ['pod', 2, 'spec', 'containers', 0, 'env', 1, 'name'] 2
# MY_POD_NAMESPACE
# values_changed pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'spec', 'containers', 0, 'env', 1, 'name'] MY_POD_NAMESPACE  =>  KUBERNETES_SERVICE_HOST
# KUBERNETES_SERVICE_PORT
# values_changed ['pod', 2, 'spec', 'containers', 0, 'env', 2, 'name'] 2
# RABBITMQ_ENABLED_PLUGINS_FILE
# values_changed pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'spec', 'containers', 0, 'env', 2, 'name'] RABBITMQ_ENABLED_PLUGINS_FILE  =>  KUBERNETES_SERVICE_PORT
# 6443
# values_changed ['pod', 2, 'spec', 'containers', 0, 'env', 2, 'value'] 2
# /operator/enabled_plugins
# values_changed pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'spec', 'containers', 0, 'env', 2, 'value'] /operator/enabled_plugins  =>  6443
# 200m
# values_changed ['pod', 2, 'spec', 'containers', 0, 'resources', 'limits', 'cpu'] 2
# 2
# values_changed pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'spec', 'containers', 0, 'resources', 'limits', 'cpu'] 2  =>  200m
# 500Mi
# values_changed ['pod', 2, 'spec', 'containers', 0, 'resources', 'limits', 'memory'] 2
# 2Gi
# values_changed pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'spec', 'containers', 0, 'resources', 'limits', 'memory'] 2Gi  =>  500Mi
# 200m
# values_changed ['pod', 2, 'spec', 'containers', 0, 'resources', 'requests', 'cpu'] 2
# 1
# values_changed pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'spec', 'containers', 0, 'resources', 'requests', 'cpu'] 1  =>  200m
# 500Mi
# values_changed ['pod', 2, 'spec', 'containers', 0, 'resources', 'requests', 'memory'] 2
# 2Gi
# values_changed pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'spec', 'containers', 0, 'resources', 'requests', 'memory'] 2Gi  =>  500Mi
# rabbitmq-cluster-operator-token-s4tkc
# values_changed ['pod', 2, 'spec', 'containers', 0, 'volumeMounts', 0, 'name'] 2
# rabbitmq-erlang-cookie
# values_changed pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'spec', 'containers', 0, 'volumeMounts', 0, 'name'] rabbitmq-erlang-cookie  =>  rabbitmq-cluster-operator-token-s4tkc
# /var/run/secrets/kubernetes.io/serviceaccount
# values_changed ['pod', 2, 'spec', 'containers', 0, 'volumeMounts', 0, 'mountPath'] 2
# /var/lib/rabbitmq/
# values_changed pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'spec', 'containers', 0, 'volumeMounts', 0, 'mountPath'] /var/lib/rabbitmq/  =>  /var/run/secrets/kubernetes.io/serviceaccount
# 10
# values_changed ['pod', 2, 'spec', 'terminationGracePeriodSeconds'] 2
# 604800
# values_changed pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'spec', 'terminationGracePeriodSeconds'] 604800  =>  10
# rabbitmq-cluster-operator
# values_changed ['pod', 2, 'spec', 'serviceAccountName'] 2
# rabbitmq-cluster-server
# values_changed pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'spec', 'serviceAccountName'] rabbitmq-cluster-server  =>  rabbitmq-cluster-operator
# rabbitmq-cluster-operator
# values_changed ['pod', 2, 'spec', 'serviceAccount'] 2
# rabbitmq-cluster-server
# values_changed pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'spec', 'serviceAccount'] rabbitmq-cluster-server  =>  rabbitmq-cluster-operator
# 1000
# values_changed ['pod', 2, 'spec', 'securityContext', 'runAsUser'] 2
# 999
# values_changed pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'spec', 'securityContext', 'runAsUser'] 999  =>  1000
# 1000
# values_changed ['pod', 2, 'spec', 'securityContext', 'runAsGroup'] 2
# 999
# values_changed pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'spec', 'securityContext', 'runAsGroup'] 999  =>  1000
# 1000
# values_changed ['pod', 2, 'spec', 'securityContext', 'fsGroup'] 2
# 999
# values_changed pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'spec', 'securityContext', 'fsGroup'] 999  =>  1000
# Running
# values_changed ['pod', 2, 'status', 'phase'] 2
# Pending
# values_changed pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'status', 'phase'] Pending  =>  Running
# Initialized
# values_changed ['pod', 2, 'status', 'conditions', 0, 'type'] 2
# PodScheduled
# values_changed pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'status', 'conditions', 0, 'type'] PodScheduled  =>  Initialized
# True
# values_changed ['pod', 2, 'status', 'conditions', 0, 'status'] 2
# False
# values_changed pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'status', 'conditions', 0, 'status'] False  =>  True
# Guaranteed
# values_changed ['pod', 2, 'status', 'qosClass'] 2
# Burstable
# values_changed pod default rabbitmq-operator-54d7687666-hxvfz ['pod', 2, 'status', 'qosClass'] Burstable  =>  Guaranteed
# observability-gap
# values_changed ['configmap', 3, 'data', 'SIEVE-MODE'] 2
# learn
# values_changed configmap default sieve-testing-global-config ['configmap', 3, 'data', 'SIEVE-MODE'] learn  =>  observability-gap
# test
# values_changed ['configmap', 3, 'data', 'SIEVE-STAGE'] 2
# learn
# values_changed configmap default sieve-testing-global-config ['configmap', 3, 'data', 'SIEVE-STAGE'] learn  =>  test
# 2
# values_changed ['statefulset', 0, 'spec', 'replicas'] 2
# 3
# values_changed statefulset default rabbitmq-cluster-server ['statefulset', 0, 'spec', 'replicas'] 3  =>  2
# 2
# values_changed ['statefulset', 0, 'status', 'replicas'] 2
# 3
# values_changed statefulset default rabbitmq-cluster-server ['statefulset', 0, 'status', 'replicas'] 3  =>  2
# 2
# values_changed ['statefulset', 0, 'status', 'currentReplicas'] 2
# 3
# values_changed statefulset default rabbitmq-cluster-server ['statefulset', 0, 'status', 'currentReplicas'] 3  =>  2
# 2
# values_changed ['statefulset', 0, 'status', 'updatedReplicas'] 2
# 3
# values_changed statefulset default rabbitmq-cluster-server ['statefulset', 0, 'status', 'updatedReplicas'] 3  =>  2
# AllPodsAreReady
# values_changed ['rabbitmqcluster', 0, 'status', 'conditions', 0, 'reason'] 2
# NotAllPodsReady
# values_changed rabbitmqcluster default rabbitmq-cluster ['rabbitmqcluster', 0, 'status', 'conditions', 0, 'reason'] NotAllPodsReady  =>  AllPodsAreReady
# True
# values_changed ['rabbitmqcluster', 0, 'status', 'conditions', 0, 'status'] 2
# False
# values_changed rabbitmqcluster default rabbitmq-cluster ['rabbitmqcluster', 0, 'status', 'conditions', 0, 'status'] False  =>  True
# Success
# values_changed ['rabbitmqcluster', 0, 'status', 'conditions', 3, 'reason'] 2
# UnsupportedOperation
# values_changed rabbitmqcluster default rabbitmq-cluster ['rabbitmqcluster', 0, 'status', 'conditions', 3, 'reason'] UnsupportedOperation  =>  Success
# True
# values_changed ['rabbitmqcluster', 0, 'status', 'conditions', 3, 'status'] 2
# False
# values_changed rabbitmqcluster default rabbitmq-cluster ['rabbitmqcluster', 0, 'status', 'conditions', 3, 'status'] False  =>  True
